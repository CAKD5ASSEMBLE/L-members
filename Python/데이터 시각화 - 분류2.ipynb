# %%
import cx_Oracle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import csv
plt.style.use('seaborn')
plt.rc('font', family = 'Malgun Gothic') # 한글 입력
plt.rcParams['axes.unicode_minus'] = False # 글꼴 변경시 마이너스 표기 가능으로 처리
import warnings
warnings.filterwarnings('ignore')
# 지수표현식 실수표현식으로 변경
pd.options.display.float_format = '{:.5f}'.format

# %%
# 패션잡화
con = cx_Oracle .connect('LM_PDB/LM@localhost:1521/xepdb1')
cursor = con.cursor()
sql ='''select 소분류명, round((sum(구매금액)/count(구매금액)),2) 평균금액 from lcl2 where 분류 = '패션잡화' group by 소분류명 order by 평균금액 desc'''
cursor.execute(sql)
x = cursor.fetchall()
columns = ['소분류명','평균금액']
updown = pd.DataFrame(x,columns=columns)
display(updown)
cursor.close()
con.commit()
con.close()
# Out:
#                  소분류명          평균금액
# 0                  보석 1629220.80000
# 1                여성피혁 1354500.00000
# 2    기타(가발포장담배연구사진수선)  501607.41000
# 3              직수입핸드백  395590.00000
# 4                  시계  377397.81000
# ..                ...           ...
# 219            여성양말기획    2840.93000
# 220            액세서리편집    2668.11000
# 221             링크스양말    2400.00000
# 222                우비    2236.38000
# 223             여성발가락    1000.00000
#
# [224 rows x 2 columns]

# %%
# 패션잡화
con = cx_Oracle .connect('LM_PDB/LM@localhost:1521/xepdb1')
cursor = con.cursor()
sql ='''select 소분류명, round((sum(구매금액)/count(구매금액)),2) 평균금액 from lcl2 where 분류 = '패션잡화' group by 소분류명 order by 평균금액 desc'''
cursor.execute(sql)
x = cursor.fetchall()
columns = ['소분류명','평균금액']
fashion = pd.DataFrame(x,columns=columns)
display(fashion)
cursor.close()
con.commit()
con.close()
# Out:
#                  소분류명          평균금액
# 0                  보석 1629220.80000
# 1                여성피혁 1354500.00000
# 2    기타(가발포장담배연구사진수선)  501607.41000
# 3              직수입핸드백  395590.00000
# 4                  시계  377397.81000
# ..                ...           ...
# 219            여성양말기획    2840.93000
# 220            액세서리편집    2668.11000
# 221             링크스양말    2400.00000
# 222                우비    2236.38000
# 223             여성발가락    1000.00000
#
# [224 rows x 2 columns]

# %%
fashion.tail(20)
# Out:
#          소분류명       평균금액
# 204   여성스타킹덧신 5175.52000
# 205    헤어악세사리 5164.53000
# 206    남성양말기획 5026.84000
# 207    남여양말세트 4700.59000
# 208     여성면덧신 4678.25000
# 209    여성양말덧신 4676.28000
# 210  여성헤어액세서리 4635.68000
# 211    여성일반양말 4483.78000
# 212       손수건 4461.54000
# 213    남성일반양말 4309.60000
# 214      정장양말 4282.20000
# 215     일회용우산 4268.40000
# 216     여성덧신류 3970.00000
# 217  성인헤어악세사리 3854.57000
# 218     슈케어용품 3097.05000
# 219    여성양말기획 2840.93000
# 220    액세서리편집 2668.11000
# 221     링크스양말 2400.00000
# 222        우비 2236.38000
# 223     여성발가락 1000.00000

# %%
sns.barplot(data=fashion,x='소분류명',y='평균금액')
plt.axhline(y = 250000) # 25만원 이상
plt.axhline(y = 50000) # 5만원 이하

# %%
# 유아동
con = cx_Oracle .connect('LM_PDB/LM@localhost:1521/xepdb1')
cursor = con.cursor()
sql ='''select 소분류명, round((sum(구매금액)/count(구매금액)),2) 평균금액 from lcl2 where 분류 = '유아동' group by 소분류명 order by 평균금액 desc'''
cursor.execute(sql)
x = cursor.fetchall()
columns = ['소분류명','평균금액']
baby = pd.DataFrame(x,columns=columns)
display(baby)
cursor.close()
con.commit()
con.close()
# Out:
#          소분류명         평균금액
# 0          분유 259841.81000
# 1      비디오게임기 232538.79000
# 2        유아침대 215750.00000
# 3       전동승용물 192786.36000
# 4     유모차/카시트 175894.89000
# ..        ...          ...
# 200     파티/팬시   3775.67000
# 201    주니어캐릭터   3773.26000
# 202      아동반장   3562.11000
# 203  유아/아동용치약   3463.37000
# 204     카드포장지   1497.05000
#
# [205 rows x 2 columns]

# %%
sns.barplot(data=baby,x='소분류명',y='평균금액')
plt.axhline(y = 135000) # 13만 5천원 이상
plt.axhline(y = 55000) # 5만 5천원 이하

# %%
# 명품
con = cx_Oracle .connect('LM_PDB/LM@localhost:1521/xepdb1')
cursor = con.cursor()
sql ='''select 소분류명, round((sum(구매금액)/count(구매금액)),2) 평균금액 from lcl2 where 분류 = '명품' group by 소분류명 order by 평균금액 desc'''
cursor.execute(sql)
x = cursor.fetchall()
columns = ['소분류명','평균금액']
luxury = pd.DataFrame(x,columns=columns)
display(luxury)
cursor.close()
con.commit()
con.close()
# Out:
#           소분류명          평균금액
# 0         명품보석 4606870.98000
# 1       명품시계기타 4425578.58000
# 2       명품잡화보석 3612413.03000
# 3        명품오디오 1598873.61000
# 4         명품잡화 1287546.82000
# 5         디자이너 1252515.11000
# 6       명품의류기타 1216069.52000
# 7          엘리든 1135744.32000
# 8        컨템포러리 1006213.05000
# 9       남성해외패션  933778.50000
# 10        수입의류  909098.67000
# 11        명품남성  648051.91000
# 12        힐앤토트  611729.16000
# 13      명품멀티기타  591025.86000
# 14        수입잡화  541596.96000
# 15      명품잡화행사  479686.42000
# 16      명품의류행사  474236.21000
# 17       명품브랜드  427318.68000
# 18         어덜트  343402.92000
# 19        명품기타  334775.63000
# 20          명품  328231.40000
# 21         직수입  281399.69000
# 22       잡화멀티샵  245536.62000
# 23         갤러리  217161.40000
# 24       주얼리멀티  169818.18000
# 25  global 편집샵   67323.56000
# 26        명품행사   42245.28000

# %%
sns.barplot(data=luxury,x='소분류명',y='평균금액')
plt.axhline(y = 3000000) # 300만원 이상
plt.axhline(y = 900000) # 90만원 이하

# %%
# 일상용품
con = cx_Oracle .connect('LM_PDB/LM@localhost:1521/xepdb1')
cursor = con.cursor()
sql ='''select 소분류명, round((sum(구매금액)/count(구매금액)),2) 평균금액 from lcl2 where 분류 = '일상용품' group by 소분류명 order by 평균금액 desc'''
cursor.execute(sql)
x = cursor.fetchall()
columns = ['소분류명','평균금액']
dn = pd.DataFrame(x,columns=columns)
display(dn)
cursor.close()
con.commit()
con.close()
# Out:
#         소분류명         평균금액
# 0         한샘 833395.87000
# 1      기능성침대 670373.16000
# 2         그림 532000.00000
# 3       소형가전 307220.00000
# 4       종합세트 285464.64000
# ..       ...          ...
# 549  여행용미용티슈   1428.95000
# 550     장바구니   1423.44000
# 551       용기   1327.14000
# 552    종량제봉투   1136.20000
# 553    재사용봉투    589.83000
#
# [554 rows x 2 columns]

# %%
sns.barplot(data=dn,x='소분류명',y='평균금액')
plt.axhline(y = 200000) # 20만원 이상
plt.axhline(y = 30000) # 3만원 이하

# %%
# 의약품/의료기기
con = cx_Oracle .connect('LM_PDB/LM@localhost:1521/xepdb1')
cursor = con.cursor()
sql ='''select 소분류명, round((sum(구매금액)/count(구매금액)),2) 평균금액 from lcl2 where 분류 = '의약품/의료기기' group by 소분류명 order by 평균금액 desc'''
cursor.execute(sql)
x = cursor.fetchall()
columns = ['소분류명','평균금액']
medicine = pd.DataFrame(x,columns=columns)
display(medicine)
cursor.close()
con.commit()
con.close()
# Out:
#          소분류명         평균금액
# 0        안마의자 245000.00000
# 1        안마용품  88086.07000
# 2       전기안마기  76557.14000
# 3        보행용품  70000.00000
# 4         찜질팩  32708.33000
# 5   온라인여성위생용품  25066.67000
# 6        건강소품  23266.67000
# 7      부직포생리대  15597.31000
# 8       일반생리대  14663.53000
# 9       순면생리대  13472.79000
# 10     매쉬형생리대  13276.97000
# 11        생리대  10913.48000
# 12      오버나이트  10151.29000
# 13         콘돔   9670.32000
# 14     삽입형생리대   9507.10000
# 15         탐폰   9062.42000
# 16     탐폰형생리대   8953.75000
# 17       생활용품   8664.29000
# 18        체온계   8000.00000
# 19     렌즈관리용품   7244.48000
# 20       의약외품   6781.74000
# 21      팬티라이너   5950.00000
# 22    온/냉찜질용품   5119.12000
# 23      건강마스크   3986.04000
# 24       침실용품   2800.00000
# 25        밴드류   2006.44000
# 26   안전상비의약외품   1901.40000

# %%
sns.barplot(data=medicine,x='소분류명',y='평균금액')
plt.axhline(y = 200000) # 20만원 이상
plt.axhline(y = 50000) # 5만원 이하
